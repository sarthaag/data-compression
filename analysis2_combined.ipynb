# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import all data and combine them together
df1 = pd.read_pickle("analysis2.1.pkl")
df2 = pd.read_pickle("analysis2.2.pkl")
df3 = pd.read_pickle("analysis2.3.pkl")

df = pd.concat([df1, df2], axis=1)

# Create X and Y lists to use for pyplot
X = [0, df3.at[0, 'RMSE32'], df3.at[0, 'RMSE16']]
Y = [1, 2, 4]
df
# Out:
#      CR2.1.100   RMSE2.1.100  CR2.1.75    RMSE2.1.75  CR2.1.50    RMSE2.1.50  \
# 0     4.148863  8.895564e-11  5.433290  2.413468e-09  7.250648  2.066075e-09
# 1     4.128169  5.342171e-11  5.414409  1.362190e-09  7.321399  1.049199e-09
# 2     3.985854  3.721427e-11  5.119674  1.065077e-09  6.837657  9.592430e-10
# 3     3.891004  3.419594e-11  5.099813  6.668726e-10  6.733937  6.549022e-10
# 4     3.999041  4.510328e-11  5.279747  9.854418e-10  6.860197  8.921002e-10
# ..         ...           ...       ...           ...       ...           ...
# 196   3.425889  9.344500e-03  4.549869  1.076258e-01  5.946827  9.852367e-02
# 197   3.333994  1.028376e-02  4.446794  1.147821e-01  5.795004  1.057475e-01
# 198   3.298053  1.137544e-02  4.424648  1.285578e-01  5.714533  1.133334e-01
# 199   3.361852  1.263808e-02  4.483221  1.408847e-01  5.828970  1.228165e-01
# 200   3.387097  1.424251e-02  4.474035  1.639391e-01  5.798102  1.387495e-01
#
#       CR2.1.25    RMSE2.1.25  CR2.2.100   RMSE2.2.100  CR2.2.75    RMSE2.2.75  \
# 0    10.538945  7.935654e-10   5.593847  8.196205e-11  7.568493  2.643968e-09
# 1    10.645278  4.895494e-10   5.970850  6.527043e-11  8.283064  1.918511e-09
# 2    10.001224  3.481931e-10   5.481357  4.644386e-11  7.444343  1.470047e-09
# 3     9.802158  4.132626e-10   5.962810  4.618577e-11  8.127816  1.172642e-09
# 4    10.002398  5.118124e-10   5.937298  4.901204e-11  8.146341  1.197685e-09
# ..         ...           ...        ...           ...       ...           ...
# 196   8.507975  3.752934e-02   5.910355  1.034624e-02  7.921284  1.306056e-01
# 197   8.275523  4.032081e-02   5.838121  1.133318e-02  7.853264  1.371299e-01
# 198   8.115479  4.539184e-02   5.736336  1.258253e-02  7.721762  1.526070e-01
# 199   8.277571  5.007920e-02   5.766874  1.402025e-02  7.715101  1.700068e-01
# 200   8.255528  6.061130e-02   5.743463  1.575256e-02  7.764857  1.988993e-01
#
#       CR2.2.50    RMSE2.2.50   CR2.2.25    RMSE2.2.25
# 0    10.601476  2.347662e-09  15.837927  2.707236e-10
# 1    11.844218  1.193409e-09  17.766327  2.515697e-10
# 2    10.630619  1.557308e-09  16.516194  1.628021e-10
# 3    11.666045  9.991263e-10  18.194956  1.228900e-10
# 4    11.708094  9.136419e-10  18.116371  1.698583e-10
# ..         ...           ...        ...           ...
# 196  11.132460  6.325086e-02  16.644178  7.228017e-03
# 197  10.985391  6.692642e-02  16.472070  7.816753e-03
# 198  10.830669  7.690388e-02  16.198913  8.861140e-03
# 199  10.907557  8.667817e-02  16.301535  9.541269e-03
# 200  10.935786  1.061134e-01  16.350593  1.205271e-02
#
# [201 rows x 16 columns]

# %%
# Analysis 2.3

plt.figure(figsize=(10, 6))
plt.scatter(X, Y, color='red')
plt.plot(X, Y, color='red')
plt.xscale("log")
plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.title("Storing Arrays to FP32 and FP16")
plt.show()

# %%
# Analysis 2.1

plt.figure(figsize=(10, 6))
plt.plot(df['RMSE2.1.100'], df['CR2.1.100'], color='red', label='100')
plt.plot(df['RMSE2.1.75'], df['CR2.1.75'], color='green', label='75')
plt.plot(df['RMSE2.1.50'], df['CR2.1.50'], color='blue', label='50')
plt.plot(df['RMSE2.1.25'], df['CR2.1.25'], color='purple', label='25')
plt.legend(title='% Quality')

plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.xscale("log")
plt.title("Plotting Arrays as 101x227 Grayscale")
plt.show()

# %%
# Analysis 2.2

plt.figure(figsize=(10, 6))
plt.plot(df['RMSE2.2.100'], df['CR2.2.100'], color='red', label='100')
plt.plot(df['RMSE2.2.75'], df['CR2.2.75'], color='green', label='75')
plt.plot(df['RMSE2.2.50'], df['CR2.2.50'], color='blue', label='50')
plt.plot(df['RMSE2.2.25'], df['CR2.2.25'], color='purple', label='25')
plt.legend(title='% Quality')

plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.xscale("log")
plt.title("Plotting Arrays as 203x203 Grayscale")
plt.show()

# %%
# Combined graphs

plt.figure(figsize=(10, 6))
plt.xscale("log")
plt.scatter(X, Y, color='red', label='Graph 1')
plt.plot(X, Y, color='red', label='Graph 1')
plt.plot(df['RMSE2.1'], df['CR2.1'], color='blue', label='Graph 2')
plt.plot(df['RMSE2.2'], df['CR2.2'], color='green', label='Graph 3')
plt.legend(loc='lower right')
plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.title("Combined Graph")
plt.show()

# %%
# # Plotting all four graphs together

# # Create 3 plots for each analysis and 1 combined plot
# figure, axis = plt.subplots(2, 2)

# axis[0, 0].plot(X, Y)
# # axis[0, 0].set_title("Storing Arrays to FP32 and FP16")

# axis[0, 1].plot(df['norm2.1'], df['CR2.1'])
# # axis[0, 1].set_title("Plotting Arrays as 101x227 Grayscale")

# axis[1, 0].plot(df['norm2.2'], df['CR2.2'])
# # axis[1, 0].set_title("Plotting Arrays as 203x203 Grayscale")

# axis[1, 1].plot(X, Y, label='1')
# axis[1, 1].plot(df['norm2.1'], df['CR2.1'], label='2')
# axis[1, 1].plot(df['norm2.2'], df['CR2.2'], label='3')
# axis[1, 1].legend()
# # axis[1, 1].set_title("Combined Plot")

# # plt.xticks([3.25,3.5,3.75,4,4.25])
# plt.show()
