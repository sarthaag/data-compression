# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import all data and combine them together
df1 = pd.read_pickle("analysis2.1.pkl")
df2 = pd.read_pickle("analysis2.2.pkl")
df3 = pd.read_pickle("analysis2.3.pkl")

df = pd.concat([df1, df2, df3], axis=1)

# Compute the avgs of norm32 and norm16
avg32 = df['norm32'].mean()
avg16 = df['norm16'].mean()

# Create X and Y lists to use for pyplot
X = [0, avg32, avg16]
Y = [1, 2, 4]
df
# Out:
#         CR2.1   norm2.1     CR2.2   norm2.2    norm32    norm16
# 0    4.148863       0.0  5.593847       0.0       0.0  0.000001
# 1    4.128169       0.0   5.97085       0.0       0.0       0.0
# 2    3.985854       0.0  5.481357       0.0       0.0       0.0
# 3    3.891004       0.0   5.96281       0.0       0.0       0.0
# 4    3.999041       0.0  5.937298       0.0       0.0       0.0
# ..        ...       ...       ...       ...       ...       ...
# 196  3.425889  1.414913  5.910355  1.566593       0.0  0.004012
# 197  3.333994  1.557132  5.838121  1.716032  0.000001  0.004319
# 198  3.298053  1.722431  5.736336  1.905204  0.000001  0.005209
# 199  3.361852  1.913616  5.766874    2.1229  0.000001  0.005853
# 200  3.387097  2.156553  5.743463    2.3852  0.000001  0.007262
#
# [201 rows x 6 columns]

# %%
# Analysis 2.3

plt.scatter(X, Y, color='red')
plt.plot(X, Y, color='red')
plt.xlabel("Average Error (Norm)")
plt.ylabel("Compression Ratio")
plt.title("Storing Arrays to FP32 and FP16")
plt.show()

# %%
# Analysis 2.1

plt.plot(df['norm2.1'], df['CR2.1'], color='blue')
plt.xlabel("Error (Norm)")
plt.ylabel("Compression Ratio")
plt.title("Plotting Arrays as 101x227 Grayscale")
plt.show()

# %%
# Analysis 2.2

plt.plot(df['norm2.2'], df['CR2.2'], color='green')
plt.xlabel("Error (Norm)")
plt.ylabel("Compression Ratio")
plt.title("Plotting Arrays as 203x203 Grayscale")
plt.show()

# %%
# Combined graphs

plt.scatter(X, Y, color='red', label='Graph 1')
plt.plot(X, Y, color='red', label='Graph 1')
plt.plot(df['norm2.1'], df['CR2.1'], color='blue', label='Graph 2')
plt.plot(df['norm2.2'], df['CR2.2'], color='green', label='Graph 3')
plt.legend()
plt.xlabel("Error (Norm)")
plt.ylabel("Compression Ratio")
plt.title("Combined Graph")
plt.show()

# %%
# Plotting all four graphs together

# Create 3 plots for each analysis and 1 combined plot
figure, axis = plt.subplots(2, 2)

axis[0, 0].plot(X, Y)
# axis[0, 0].set_title("Storing Arrays to FP32 and FP16")

axis[0, 1].plot(df['norm2.1'], df['CR2.1'])
# axis[0, 1].set_title("Plotting Arrays as 101x227 Grayscale")

axis[1, 0].plot(df['norm2.2'], df['CR2.2'])
# axis[1, 0].set_title("Plotting Arrays as 203x203 Grayscale")

axis[1, 1].plot(X, Y, label='1')
axis[1, 1].plot(df['norm2.1'], df['CR2.1'], label='2')
axis[1, 1].plot(df['norm2.2'], df['CR2.2'], label='3')
axis[1, 1].legend()
# axis[1, 1].set_title("Combined Plot")

# plt.xticks([3.25,3.5,3.75,4,4.25])
plt.show()
