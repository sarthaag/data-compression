# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import all data
df1 = pd.read_pickle("analysis2.1.pkl")
df2 = pd.read_pickle("analysis2.2.pkl")
df3 = pd.read_pickle("analysis2.3.pkl")
df4 = pd.read_pickle("analysis2.4.pkl")

df = pd.concat([df1, df2], axis=1)

# Create X and Y lists to use for pyplot
X = [df3.at[0, 'RMSE32'], df3.at[0, 'RMSE16']]
Y = [2, 4]

# %%
# Analysis 2.3

plt.figure(figsize=(10, 6))
plt.scatter(X, Y, color='red')
plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.title("Storing Arrays to FP32 and FP16")
plt.show()

# %%
# Analysis 2.1

plt.figure(figsize=(10, 6))
plt.scatter(df['RMSE2.1.95'], df['CR2.1.95'], color='red', label='95', marker='.')
plt.scatter(df['RMSE2.1.75'], df['CR2.1.75'], color='green', label='75', marker='.')
plt.scatter(df['RMSE2.1.50'], df['CR2.1.50'], color='blue', label='50', marker='.')
plt.scatter(df['RMSE2.1.25'], df['CR2.1.25'], color='purple', label='25', marker='.')
plt.legend(title='% Quality', bbox_to_anchor=(1.0, 1.017))

# Plotting the mean for each quality
plt.scatter(df['RMSE2.1.95'].mean(axis=0), df['CR2.1.95'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.1.75'].mean(axis=0), df['CR2.1.75'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.1.50'].mean(axis=0), df['CR2.1.50'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.1.25'].mean(axis=0), df['CR2.1.25'].mean(axis=0), color='black', marker='D')

plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.title("Plotting Arrays as 101x227 Grayscale")
plt.show()

# %%
# Analysis 2.2

plt.figure(figsize=(10, 6))
plt.scatter(df['RMSE2.2.95'], df['CR2.2.95'], color='red', label='95', marker='.')
plt.scatter(df['RMSE2.2.75'], df['CR2.2.75'], color='green', label='75', marker='.')
plt.scatter(df['RMSE2.2.50'], df['CR2.2.50'], color='blue', label='50', marker='.')
plt.scatter(df['RMSE2.2.25'], df['CR2.2.25'], color='purple', label='25', marker='.')
plt.legend(title='% Quality', bbox_to_anchor=(1.0, 1.017))

# Plotting the mean for each quality
plt.scatter(df['RMSE2.2.95'].mean(axis=0), df['CR2.2.95'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.2.75'].mean(axis=0), df['CR2.2.75'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.2.50'].mean(axis=0), df['CR2.2.50'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.2.25'].mean(axis=0), df['CR2.2.25'].mean(axis=0), color='black', marker='D')

plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.title("Plotting Arrays as 203x203 Grayscale")
plt.show()

# %%
# Analysis 2.4

plt.figure(figsize=(10, 6))
plt.scatter(df4['RMSE1D_k=1_ax=0'], df4['CR1D_k=1_ax=0'], color='red', label='1D,k=1,r')
plt.scatter(df4['RMSE1D_k=2_ax=0'], df4['CR1D_k=2_ax=0'], color='green', label='1D,k=2,r')
plt.scatter(df4['RMSE1D_k=5_ax=0'], df4['CR1D_k=5_ax=0'], color='blue', label='1D,k=5,r')
plt.scatter(df4['RMSE1D_k=10_ax=0'], df4['CR1D_k=10_ax=0'], color='purple', label='1D,k=10,r')
plt.scatter(df4['RMSE1D_k=20_ax=0'], df4['CR1D_k=20_ax=0'], color='orange', label='1D,k=20,r')
plt.scatter(df4['RMSE1D_k=50_ax=0'], df4['CR1D_k=50_ax=0'], color='olive', label='1D,k=50,r')
plt.scatter(df4['RMSE1D_k=75_ax=0'], df4['CR1D_k=75_ax=0'], color='cyan', label='1D,k=75,r')
plt.scatter(df4['RMSE1D_k=100_ax=0'], df4['CR1D_k=100_ax=0'], color='pink', label='1D,k=100,r')

plt.scatter(df4['RMSE1D_k=1_ax=1'], df4['CR1D_k=1_ax=1'], color='red', label='1D,k=1,z', marker='^')
plt.scatter(df4['RMSE1D_k=2_ax=1'], df4['CR1D_k=2_ax=1'], color='green', label='1D,k=2,z', marker='^')
plt.scatter(df4['RMSE1D_k=5_ax=1'], df4['CR1D_k=5_ax=1'], color='blue', label='1D,k=5,z', marker='^')
plt.scatter(df4['RMSE1D_k=10_ax=1'], df4['CR1D_k=10_ax=1'], color='purple', label='1D,k=10,z', marker='^')
plt.scatter(df4['RMSE1D_k=20_ax=1'], df4['CR1D_k=20_ax=1'], color='orange', label='1D,k=20,z', marker='^')
plt.scatter(df4['RMSE1D_k=50_ax=1'], df4['CR1D_k=50_ax=1'], color='olive', label='1D,k=50,z', marker='^')
plt.scatter(df4['RMSE1D_k=75_ax=1'], df4['CR1D_k=75_ax=1'], color='cyan', label='1D,k=75,z', marker='^')
plt.scatter(df4['RMSE1D_k=100_ax=1'], df4['CR1D_k=100_ax=1'], color='pink', label='1D,k=100,z', marker='^')

plt.scatter(df4['RMSE2D_k=1'], df4['CR2D_k=1'], color='red', label='2D,k=1', marker='s')
plt.scatter(df4['RMSE2D_k=2'], df4['CR2D_k=2'], color='green', label='2D,k=2', marker='s')
plt.scatter(df4['RMSE2D_k=5'], df4['CR2D_k=5'], color='blue', label='2D,k=5', marker='s')
plt.scatter(df4['RMSE2D_k=10'], df4['CR2D_k=10'], color='purple', label='2D,k=10', marker='s')
plt.scatter(df4['RMSE2D_k=20'], df4['CR2D_k=20'], color='orange', label='2D,k=20', marker='s')
plt.scatter(df4['RMSE2D_k=50'], df4['CR2D_k=50'], color='olive', label='2D,k=50', marker='s')
plt.scatter(df4['RMSE2D_k=75'], df4['CR2D_k=75'], color='cyan', label='2D,k=75', marker='s')
plt.scatter(df4['RMSE2D_k=100'], df4['CR2D_k=100'], color='pink', label='2D,k=100', marker='s')

plt.legend(bbox_to_anchor=(1.19, 1.017))
plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.yscale("log")
plt.title("1D and 2D FFTs Keeping Top k Modes")
plt.show()

# %%
# Combined graphs

plt.figure(figsize=(10, 6))

plt.scatter(X, Y, color='gray', label='Graph 1')

# 2.1
plt.scatter(df['RMSE2.1.95'], df['CR2.1.95'], color='red', label='2-95%', marker='.')
plt.scatter(df['RMSE2.1.75'], df['CR2.1.75'], color='green', label='2-75%', marker='.')
plt.scatter(df['RMSE2.1.50'], df['CR2.1.50'], color='blue', label='2-50%', marker='.')
plt.scatter(df['RMSE2.1.25'], df['CR2.1.25'], color='purple', label='2-25%', marker='.')

# Plotting the mean for each quality
plt.scatter(df['RMSE2.1.95'].mean(axis=0), df['CR2.1.95'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.1.75'].mean(axis=0), df['CR2.1.75'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.1.50'].mean(axis=0), df['CR2.1.50'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.1.25'].mean(axis=0), df['CR2.1.25'].mean(axis=0), color='black', marker='D')

# 2.2
plt.scatter(df['RMSE2.2.95'], df['CR2.2.95'], color='orange', label='3-95%', marker='.')
plt.scatter(df['RMSE2.2.75'], df['CR2.2.75'], color='olive', label='3-75%', marker='.')
plt.scatter(df['RMSE2.2.50'], df['CR2.2.50'], color='cyan', label='3-50%', marker='.')
plt.scatter(df['RMSE2.2.25'], df['CR2.2.25'], color='pink', label='3-25%', marker='.')

# Plotting the mean for each quality
plt.scatter(df['RMSE2.2.95'].mean(axis=0), df['CR2.2.95'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.2.75'].mean(axis=0), df['CR2.2.75'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.2.50'].mean(axis=0), df['CR2.2.50'].mean(axis=0), color='black', marker='D')
plt.scatter(df['RMSE2.2.25'].mean(axis=0), df['CR2.2.25'].mean(axis=0), color='black', marker='D')

plt.legend(title='% Quality', bbox_to_anchor=(1.0, 1.017))
plt.xlabel("RMSE")
plt.ylabel("Compression Ratio")
plt.title("Combined Graph")
plt.show()

# %%
# # Plotting all four graphs together

# # Create 3 plots for each analysis and 1 combined plot
# figure, axis = plt.subplots(2, 2)

# axis[0, 0].plot(X, Y)
# # axis[0, 0].set_title("Storing Arrays to FP32 and FP16")

# axis[0, 1].plot(df['norm2.1'], df['CR2.1'])
# # axis[0, 1].set_title("Plotting Arrays as 101x227 Grayscale")

# axis[1, 0].plot(df['norm2.2'], df['CR2.2'])
# # axis[1, 0].set_title("Plotting Arrays as 203x203 Grayscale")

# axis[1, 1].plot(X, Y, label='1')
# axis[1, 1].plot(df['norm2.1'], df['CR2.1'], label='2')
# axis[1, 1].plot(df['norm2.2'], df['CR2.2'], label='3')
# axis[1, 1].legend()
# # axis[1, 1].set_title("Combined Plot")

# # plt.xticks([3.25,3.5,3.75,4,4.25])
# plt.show()
